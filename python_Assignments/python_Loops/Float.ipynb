# %%
# Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577
numbers = [3.14, 2.718, 1.618, 0.577]
average = sum(numbers) / len(numbers)
print(f"The average is: {average}")
# Out:
# The average is: 2.01325

# %%
# Question 2: Convert 5.75 to an integer and print the result
float_number = 5.75
int_number = int(float_number)
print(f"The integer value of {float_number} is: {int_number}")
# Out:
# The integer value of 5.75 is: 5

# %%
# Question 3: Multiply 0.1, 0.2, and 0.3 and print the result
result = 0.1 * 0.2 * 0.3
print(f"The result of multiplying 0.1, 0.2, and 0.3 is: {result}")
# Out:
# The result of multiplying 0.1, 0.2, and 0.3 is: 0.006000000000000001

# %%
# Question 4: Find the maximum value among 7.5, 3.6, 9.8, 2.4 and print it
numbers = [7.5, 3.6, 9.8, 2.4]
max_value = max(numbers)
print(f"The maximum value is: {max_value}")
# Out:
# The maximum value is: 9.8
